# %%
import tensorflow as tf
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.utils import pad_sequences

vocab_size = 10000
maxlength = 200

(x_train,y_train), (x_test,y_test) = reuters.load_data(num_words = vocab_size)

x_train = pad_sequences(x_train,maxlength)
x_test = pad_sequences(x_test,maxlength)

model = Sequential([
    Embedding(input_dim=vocab_size,output_dim=64,input_length=maxlength),
    GRU(64),
    Dense(46,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=256,
    validation_split=0.2
)

test_loss,test_accuracy = model.evaluate(x_test,y_test)

print("Test Loss: ",test_loss)
print("Test Accuracy: ",test_accuracy)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 606ms/step - accuracy: 0.3396 - loss: 3.1853 - val_accuracy: 0.3450 - val_loss: 2.4618
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 593ms/step - accuracy: 0.3534 - loss: 2.3320 - val_accuracy: 0.3506 - val_loss: 2.2277
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.3950 - loss: 2.1108 - val_accuracy: 0.4073 - val_loss: 2.0259
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 588ms/step - accuracy: 0.4285 - loss: 1.9361 - val_accuracy: 0.4602 - val_loss: 1.9107
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 603ms/step - accuracy: 0.5012 - loss: 1.7921 - val_accuracy: 0.4997 - val_loss: 1.8242
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 605ms/step - accuracy: 0.5499 - loss: 1.6791 - val_accuracy: 0.5248 - val_loss: 1.8001
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 602ms/step - accuracy: 0.5605 - loss: 1.6141 - val_accuracy: 0.5426 - val_loss: 1.7754
# Epoch 8/50
# ...

# %%
import numpy as np
pred = model.predict(x_test[101:102])

print("Predicted Class:", np.argmax(pred))
print("Actual Class:", y_test[101])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predicted Class: 3
# Actual Class: 1
