# %% [markdown]
# Implementation of OR, AND, NOR NOT, XOR Gate using Backpropagation in Neural Networks.

# %% [markdown]
# ### Import Libraries and Define Neural Network

# %%
import numpy as np

class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size, learning_rate=0.1):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.learning_rate = learning_rate

        # Initialize weights and biases
        # Weights from input to hidden layer
        self.weights_ih = np.random.randn(self.input_size, self.hidden_size)
        self.bias_h = np.random.randn(self.hidden_size)

        # Weights from hidden to output layer
        self.weights_ho = np.random.randn(self.hidden_size, self.output_size)
        self.bias_o = np.random.randn(self.output_size)

    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def _sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward(self, inputs):
        # Hidden layer
        self.hidden_input = np.dot(inputs, self.weights_ih) + self.bias_h
        self.hidden_output = self._sigmoid(self.hidden_input)

        # Output layer
        self.final_input = np.dot(self.hidden_output, self.weights_ho) + self.bias_o
        self.final_output = self._sigmoid(self.final_input)
        return self.final_output

    def backward(self, inputs, targets, outputs):

        output_error = targets - outputs
        output_delta = output_error * self._sigmoid_derivative(outputs)

        hidden_error = np.dot(output_delta, self.weights_ho.T)
        hidden_delta = hidden_error * self._sigmoid_derivative(self.hidden_output)

        # Update weights and biases
        # Hidden to output weights
        self.weights_ho += np.dot(self.hidden_output.T, output_delta) * self.learning_rate
        self.bias_o += np.sum(output_delta, axis=0) * self.learning_rate

        # Input to hidden weights
        self.weights_ih += np.dot(inputs.T, hidden_delta) * self.learning_rate
        self.bias_h += np.sum(hidden_delta, axis=0) * self.learning_rate

    def train(self, inputs, targets, epochs):
        for epoch in range(epochs):
            output = self.forward(inputs)
            self.backward(inputs, targets, output)

# %% [markdown]
# ### Step 2: Implement the OR Gate
#
# Now, let's use our `NeuralNetwork` class to implement the OR gate. An OR gate outputs `1` if at least one of its inputs is `1`, and `0` otherwise.

# %%
or_inputs = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
or_targets = np.array([[0], [1], [1], [1]])

or_nn = NeuralNetwork(input_size=2, hidden_size=2, output_size=1)
or_nn.train(or_inputs, or_targets, epochs=10000)

print("OR Gate Predictions:")
for i, input_val in enumerate(or_inputs):
    prediction = or_nn.forward(input_val)
    print(f"Input: {input_val}, Target: {or_targets[i]}, Prediction: {prediction[0]:.4f} (Rounded: {round(prediction[0])})")
# Out:
# OR Gate Predictions:
# Input: [0 0], Target: [0], Prediction: 0.0358 (Rounded: 0)
# Input: [0 1], Target: [1], Prediction: 0.9765 (Rounded: 1)
# Input: [1 0], Target: [1], Prediction: 0.9779 (Rounded: 1)
# Input: [1 1], Target: [1], Prediction: 0.9947 (Rounded: 1)

# %%
# AND gate training data
and_inputs = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
and_targets = np.array([[0], [0], [0], [1]])

# Initialize and train the neural network for AND gate
and_nn = NeuralNetwork(input_size=2, hidden_size=2, output_size=1)
and_nn.train(and_inputs, and_targets, epochs=10000)

print("\nAND Gate Predictions:")
for i, input_val in enumerate(and_inputs):
    prediction = and_nn.forward(input_val)
    print(f"Input: {input_val}, Target: {and_targets[i]}, Prediction: {prediction[0]:.4f} (Rounded: {round(prediction[0])})")
# Out:
# AND Gate Predictions:
# Input: [0 0], Target: [0], Prediction: 0.0021 (Rounded: 0)
# Input: [0 1], Target: [0], Prediction: 0.0298 (Rounded: 0)
# Input: [1 0], Target: [0], Prediction: 0.0264 (Rounded: 0)
# Input: [1 1], Target: [1], Prediction: 0.9612 (Rounded: 1)

# %%
# XOR gate training data
xor_inputs = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
xor_targets = np.array([[0], [1], [1], [0]])

# Initialize and train the neural network for XOR gate
xor_nn = NeuralNetwork(input_size=2, hidden_size=2, output_size=1)
xor_nn.train(xor_inputs, xor_targets, epochs=10000)

print("\nXOR Gate Predictions:")
for i, input_val in enumerate(xor_inputs):
    prediction = xor_nn.forward(input_val)
    print(f"Input: {input_val}, Target: {xor_targets[i]}, Prediction: {prediction[0]:.4f} (Rounded: {round(prediction[0])})")
# Out:
# XOR Gate Predictions:
# Input: [0 0], Target: [0], Prediction: 0.0451 (Rounded: 0)
# Input: [0 1], Target: [1], Prediction: 0.9581 (Rounded: 1)
# Input: [1 0], Target: [1], Prediction: 0.9493 (Rounded: 1)
# Input: [1 1], Target: [0], Prediction: 0.0394 (Rounded: 0)
